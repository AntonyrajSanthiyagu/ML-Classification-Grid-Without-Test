# %%
import pandas as pd

# %%
dataset=pd.read_csv("CKD.csv")

# %%
dataset
# Out:
#            age         bp sg   al   su     rbc        pc         pcc  \
# 0     2.000000  76.459948  c  3.0  0.0  normal  abnormal  notpresent
# 1     3.000000  76.459948  c  2.0  0.0  normal    normal  notpresent
# 2     4.000000  76.459948  a  1.0  0.0  normal    normal  notpresent
# 3     5.000000  76.459948  d  1.0  0.0  normal    normal  notpresent
# 4     5.000000  50.000000  c  0.0  0.0  normal    normal  notpresent
# ..         ...        ... ..  ...  ...     ...       ...         ...
# 394  51.492308  70.000000  a  0.0  0.0  normal    normal  notpresent
# 395  51.492308  70.000000  c  0.0  2.0  normal    normal  notpresent
# 396  51.492308  70.000000  c  3.0  0.0  normal    normal  notpresent
# 397  51.492308  90.000000  a  0.0  0.0  normal    normal  notpresent
# 398  51.492308  80.000000  a  0.0  0.0  normal    normal  notpresent
#
#              ba         bgr  ...        pcv            wc        rc  htn   dm  \
# 0    notpresent  148.112676  ...  38.868902   8408.191126  4.705597   no   no
# 1    notpresent  148.112676  ...  34.000000  12300.000000  4.705597   no   no
# 2    notpresent   99.000000  ...  34.000000   8408.191126  4.705597   no   no
# 3    notpresent  148.112676  ...  38.868902   8408.191126  4.705597   no   no
# 4    notpresent  148.112676  ...  36.000000  12400.000000  4.705597   no   no
# ..          ...         ...  ...        ...           ...       ...  ...  ...
# 394  notpresent  219.000000  ...  37.000000   9800.000000  4.400000   no   no
# 395  notpresent  220.000000  ...  27.000000   8408.191126  4.705597  yes  yes
# 396  notpresent  110.000000  ...  26.000000   9200.000000  3.400000  yes  yes
# 397  notpresent  207.000000  ...  38.868902   8408.191126  4.705597  yes  yes
# 398  notpresent  100.000000  ...  53.000000   8500.000000  4.900000   no   no
#
#      cad  appet    pe  ane classification
# 0     no    yes   yes   no            yes
# 1     no    yes  poor   no            yes
# 2     no    yes  poor   no            yes
# 3     no    yes  poor  yes            yes
# 4     no    yes  poor   no            yes
# ..   ...    ...   ...  ...            ...
# 394   no    yes  poor   no            yes
# 395   no    yes  poor  yes            yes
# 396   no   poor  poor   no            yes
# 397   no    yes  poor  yes            yes
# 398   no    yes  poor   no             no
#
# [399 rows x 25 columns]

# %%
dataset=pd.get_dummies(dataset,drop_first=True)

# %%
dataset
# Out:
#            age         bp   al   su         bgr          bu        sc  \
# 0     2.000000  76.459948  3.0  0.0  148.112676   57.482105  3.077356
# 1     3.000000  76.459948  2.0  0.0  148.112676   22.000000  0.700000
# 2     4.000000  76.459948  1.0  0.0   99.000000   23.000000  0.600000
# 3     5.000000  76.459948  1.0  0.0  148.112676   16.000000  0.700000
# 4     5.000000  50.000000  0.0  0.0  148.112676   25.000000  0.600000
# ..         ...        ...  ...  ...         ...         ...       ...
# 394  51.492308  70.000000  0.0  0.0  219.000000   36.000000  1.300000
# 395  51.492308  70.000000  0.0  2.0  220.000000   68.000000  2.800000
# 396  51.492308  70.000000  3.0  0.0  110.000000  115.000000  6.000000
# 397  51.492308  90.000000  0.0  0.0  207.000000   80.000000  6.800000
# 398  51.492308  80.000000  0.0  0.0  100.000000   49.000000  1.000000
#
#             sod       pot       hrmo  ...  pc_normal  pcc_present  ba_present  \
# 0    137.528754  4.627244  12.518156  ...      False        False       False
# 1    137.528754  4.627244  10.700000  ...       True        False       False
# 2    138.000000  4.400000  12.000000  ...       True        False       False
# 3    138.000000  3.200000   8.100000  ...       True        False       False
# 4    137.528754  4.627244  11.800000  ...       True        False       False
# ..          ...       ...        ...  ...        ...          ...         ...
# 394  139.000000  3.700000  12.500000  ...       True        False       False
# 395  137.528754  4.627244   8.700000  ...       True        False       False
# 396  134.000000  2.700000   9.100000  ...       True        False       False
# 397  142.000000  5.500000   8.500000  ...       True        False       False
# 398  140.000000  5.000000  16.300000  ...       True        False       False
#
#      htn_yes  dm_yes  cad_yes  appet_yes  pe_yes  ane_yes  classification_yes
# 0      False   False    False       True    True    False                True
# 1      False   False    False       True   False    False                True
# 2      False   False    False       True   False    False                True
# 3      False   False    False       True   False     True                True
# 4      False   False    False       True   False    False                True
# ..       ...     ...      ...        ...     ...      ...                 ...
# 394    False   False    False       True   False    False                True
# 395     True    True    False       True   False     True                True
# 396     True    True    False      False   False    False                True
# 397     True    True    False       True   False     True                True
# 398    False   False    False       True   False    False               False
#
# [399 rows x 28 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bp', 'al', 'su', 'bgr', 'bu', 'sc', 'sod', 'pot', 'hrmo', 'pcv',
#        'wc', 'rc', 'sg_b', 'sg_c', 'sg_d', 'sg_e', 'rbc_normal', 'pc_normal',
#        'pcc_present', 'ba_present', 'htn_yes', 'dm_yes', 'cad_yes',
#        'appet_yes', 'pe_yes', 'ane_yes', 'classification_yes'],
#       dtype='object')

# %%
dataset["classification_yes"].value_counts()
# Out:
# classification_yes
# True     249
# False    150
# Name: count, dtype: int64

# %%
independent=dataset[['age', 'bp', 'al', 'su', 'bgr', 'bu', 'sc', 'sod', 'pot', 'hrmo', 'pcv',
       'wc', 'rc', 'sg_b', 'sg_c', 'sg_d', 'sg_e', 'rbc_normal', 'pc_normal',
       'pcc_present', 'ba_present', 'htn_yes', 'dm_yes', 'cad_yes',
       'appet_yes', 'pe_yes', 'ane_yes']]
independent
# Out:
#            age         bp   al   su         bgr          bu        sc  \
# 0     2.000000  76.459948  3.0  0.0  148.112676   57.482105  3.077356
# 1     3.000000  76.459948  2.0  0.0  148.112676   22.000000  0.700000
# 2     4.000000  76.459948  1.0  0.0   99.000000   23.000000  0.600000
# 3     5.000000  76.459948  1.0  0.0  148.112676   16.000000  0.700000
# 4     5.000000  50.000000  0.0  0.0  148.112676   25.000000  0.600000
# ..         ...        ...  ...  ...         ...         ...       ...
# 394  51.492308  70.000000  0.0  0.0  219.000000   36.000000  1.300000
# 395  51.492308  70.000000  0.0  2.0  220.000000   68.000000  2.800000
# 396  51.492308  70.000000  3.0  0.0  110.000000  115.000000  6.000000
# 397  51.492308  90.000000  0.0  0.0  207.000000   80.000000  6.800000
# 398  51.492308  80.000000  0.0  0.0  100.000000   49.000000  1.000000
#
#             sod       pot       hrmo  ...  rbc_normal  pc_normal  pcc_present  \
# 0    137.528754  4.627244  12.518156  ...        True      False        False
# 1    137.528754  4.627244  10.700000  ...        True       True        False
# 2    138.000000  4.400000  12.000000  ...        True       True        False
# 3    138.000000  3.200000   8.100000  ...        True       True        False
# 4    137.528754  4.627244  11.800000  ...        True       True        False
# ..          ...       ...        ...  ...         ...        ...          ...
# 394  139.000000  3.700000  12.500000  ...        True       True        False
# 395  137.528754  4.627244   8.700000  ...        True       True        False
# 396  134.000000  2.700000   9.100000  ...        True       True        False
# 397  142.000000  5.500000   8.500000  ...        True       True        False
# 398  140.000000  5.000000  16.300000  ...        True       True        False
#
#      ba_present  htn_yes  dm_yes  cad_yes  appet_yes  pe_yes  ane_yes
# 0         False    False   False    False       True    True    False
# 1         False    False   False    False       True   False    False
# 2         False    False   False    False       True   False    False
# 3         False    False   False    False       True   False     True
# 4         False    False   False    False       True   False    False
# ..          ...      ...     ...      ...        ...     ...      ...
# 394       False    False   False    False       True   False    False
# 395       False     True    True    False       True   False     True
# 396       False     True    True    False      False   False    False
# 397       False     True    True    False       True   False     True
# 398       False    False   False    False       True   False    False
#
# [399 rows x 27 columns]

# %%
dependent=dataset[['classification_yes']]
dependent
# Out:
#      classification_yes
# 0                  True
# 1                  True
# 2                  True
# 3                  True
# 4                  True
# ..                  ...
# 394                True
# 395                True
# 396                True
# 397                True
# 398               False
#
# [399 rows x 1 columns]

# %%
independent.shape
# Out:
# (399, 27)

# %%
dependent.shape
# Out:
# (399, 1)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
independent=sc.fit_transform(independent)

# %%
from sklearn.neighbors import KNeighborsClassifier

from sklearn.model_selection import GridSearchCV

param_grid = {'n_neighbors':[1,5,7,10],
              'metric':['minkowski'],
              'weights':['uniform', 'distance'],
              'algorithm':['auto', 'ball_tree', 'kd_tree', 'brute'],
              'p':[2]} 



grid = GridSearchCV(KNeighborsClassifier(), param_grid, refit = True, verbose = 3,n_jobs=-1,scoring='f1_weighted') 

grid.fit(independent, dependent)
# Out:
# Fitting 5 folds for each of 32 candidates, totalling 160 fits
# C:\Anaconda 3\Lib\site-packages\sklearn\neighbors\_classification.py:238: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# GridSearchCV(estimator=KNeighborsClassifier(), n_jobs=-1,
#              param_grid={'algorithm': ['auto', 'ball_tree', 'kd_tree', 'brute'],
#                          'metric': ['minkowski'], 'n_neighbors': [1, 5, 7, 10],
#                          'p': [2], 'weights': ['uniform', 'distance']},
#              scoring='f1_weighted', verbose=3)

# %%
result=grid.cv_results_
#print(result)

y_pred = grid.predict(independent)
#print(y_pred)
   
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(dependent, y_pred)
#print(cm)

from sklearn.metrics import classification_report

clf_report = classification_report(dependent, y_pred)

#print(clf_report)
# Out:
# C:\Anaconda 3\Lib\site-packages\joblib\externals\loky\backend\context.py:136: UserWarning: Could not find the number of physical cores for the following reason:
# invalid literal for int() with base 10: ''
# Returning the number of logical cores instead. You can silence this warning by setting LOKY_MAX_CPU_COUNT to the number of cores you want to use.
#   warnings.warn(
#   File "C:\Anaconda 3\Lib\site-packages\joblib\externals\loky\backend\context.py", line 268, in _count_physical_cores
#     cpu_count_physical = sum(map(int, cpu_info))
#                          ^^^^^^^^^^^^^^^^^^^^^^^

# %%
from sklearn.metrics import f1_score

f1_macro=f1_score(dependent,y_pred,average='weighted')

print("The f1_macro value for best parameter {}:".format(grid.best_params_),f1_macro)
# Out:
# The f1_macro value for best parameter {'algorithm': 'auto', 'metric': 'minkowski', 'n_neighbors': 1, 'p': 2, 'weights': 'uniform'}: 1.0

# %%
print("The confusion Matrix:\n",cm)
# Out:
# The confusion Matrix:
#  [[150   0]
#  [  0 249]]

# %%
print("The report:\n",clf_report)
# Out:
# The report:
#                precision    recall  f1-score   support
#
#        False       1.00      1.00      1.00       150
#         True       1.00      1.00      1.00       249
#
#     accuracy                           1.00       399
#    macro avg       1.00      1.00      1.00       399
# weighted avg       1.00      1.00      1.00       399

# %%
#AUC ROC stands for “Area Under the Curve” of the “Receiver Operating Characteristic” curve. 
from sklearn.metrics import roc_auc_score

roc_auc_score(dependent,grid.predict_proba(independent)[:,1])
# Out:
# 1.0

# %%
table=pd.DataFrame.from_dict(result)

table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.345653      0.174321         3.190981        1.308524
# 1        0.020130      0.019495         0.730490        0.190569
# 2        0.066322      0.031083         0.737776        0.185068
# 3        0.036003      0.032886         0.585584        0.090910
# 4        0.022655      0.013835         0.521688        0.028526
# 5        0.041832      0.026059         0.671320        0.097529
# 6        0.075395      0.076808         0.597971        0.070191
# 7        0.047402      0.023630         0.490347        0.023992
# 8        0.051562      0.025944         0.093696        0.019780
# 9        0.032696      0.007270         0.042598        0.007725
# 10       0.020719      0.004546         0.073164        0.006638
# 11       0.034686      0.021795         0.062889        0.011020
# 12       0.034892      0.030482         0.082250        0.007618
# 13       0.021597      0.009801         0.034612        0.002747
# 14       0.053679      0.025752         0.086343        0.017399
# 15       0.045839      0.013270         0.056392        0.007182
# 16       0.048371      0.014251         0.064751        0.004965
# 17       0.032626      0.015785         0.041064        0.007000
# 18       0.035083      0.014842         0.058695        0.008005
# 19       0.061019      0.049975         0.046320        0.015231
# 20       0.037076      0.020144         0.069576        0.009555
# 21       0.039260      0.023869         0.040812        0.007540
# 22       0.018210      0.007835         0.077739        0.008537
# 23       0.039386      0.022285         0.029223        0.002882
# 24       0.060005      0.025525         0.510499        0.019042
# 25       0.035091      0.020272         0.511078        0.036937
# 26       0.029198      0.027577         0.450249        0.052523
# 27       0.021852      0.013470         0.447030        0.026440
# 28       0.030382      0.015868         0.441168        0.035401
# 29       0.017640      0.009378         0.490325        0.029632
# 30       0.022403      0.010813         0.426117        0.024806
# 31       0.014612      0.011532         0.415091        0.063031
#
#    param_algorithm param_metric param_n_neighbors param_p param_weights  \
# 0             auto    minkowski                 1       2       uniform
# 1             auto    minkowski                 1       2      distance
# 2             auto    minkowski                 5       2       uniform
# 3             auto    minkowski                 5       2      distance
# 4             auto    minkowski                 7       2       uniform
# 5             auto    minkowski                 7       2      distance
# 6             auto    minkowski                10       2       uniform
# 7             auto    minkowski                10       2      distance
# 8        ball_tree    minkowski                 1       2       uniform
# 9        ball_tree    minkowski                 1       2      distance
# 10       ball_tree    minkowski                 5       2       uniform
# 11       ball_tree    minkowski                 5       2      distance
# 12       ball_tree    minkowski                 7       2       uniform
# 13       ball_tree    minkowski                 7       2      distance
# 14       ball_tree    minkowski                10       2       uniform
# 15       ball_tree    minkowski                10       2      distance
# 16         kd_tree    minkowski                 1       2       uniform
# 17         kd_tree    minkowski                 1       2      distance
# 18         kd_tree    minkowski                 5       2       uniform
# 19         kd_tree    minkowski                 5       2      distance
# 20         kd_tree    minkowski                 7       2       uniform
# 21         kd_tree    minkowski                 7       2      distance
# 22         kd_tree    minkowski                10       2       uniform
# 23         kd_tree    minkowski                10       2      distance
# 24           brute    minkowski                 1       2       uniform
# 25           brute    minkowski                 1       2      distance
# 26           brute    minkowski                 5       2       uniform
# 27           brute    minkowski                 5       2      distance
# 28           brute    minkowski                 7       2       uniform
# 29           brute    minkowski                 7       2      distance
# 30           brute    minkowski                10       2       uniform
# 31           brute    minkowski                10       2      distance
#
#                                                params  split0_test_score  \
# 0   {'algorithm': 'auto', 'metric': 'minkowski', '...           0.913778
# 1   {'algorithm': 'auto', 'metric': 'minkowski', '...           0